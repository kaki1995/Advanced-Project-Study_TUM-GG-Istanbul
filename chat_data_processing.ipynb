# %%
# Import relevant libaries

import pandas as pd
import os
from pathlib import Path

# %% [markdown]
# ### 1.1. Import participants_rows.csv file and drop duplicates

# %%
# Load the participants_rows.csv file
data_dir = Path('chat_data_20251121_1801')
df_participant = pd.read_csv(data_dir / 'participants_rows.csv', sep=',')

# Preview the dataset
df_participant.head()
# Out:
#                          participant_id                     created_at  \
# 0  fe4a79bb-642e-49d8-920a-a5f39035ffe3  2025-11-20 16:22:11.281835+00
# 1  228fff26-6609-4d09-a10b-94449cfcc4a2   2025-11-20 16:22:10.68133+00
# 2  5b24e045-facc-4697-998c-3a72d57a42e6  2025-11-20 16:22:10.134939+00
# 3  ddebd93e-0d14-4d91-b2af-3e9647c3d695  2025-11-20 16:22:10.134909+00
# 4  151939c4-8aae-490b-92eb-c7d353a4a95c  2025-11-18 18:15:57.927115+00
#
#                                   ip_address device_type
# 0   84.17.45.206,84.17.45.206, 99.82.172.145     desktop
# 1   84.17.45.206,84.17.45.206, 99.82.172.144     desktop
# 2   84.17.45.206,84.17.45.206, 99.82.172.144     desktop
# 3   84.17.45.206,84.17.45.206, 99.82.172.144     desktop
# 4  193.197.8.143,193.197.8.143, 99.82.163.77     desktop

# %%
# Check for duplicates based on participant_id
duplicates = df_participant[df_participant.duplicated('participant_id', keep=False)]
print(f"Number of duplicate rows: {len(duplicates)}")
duplicates.head()

# Count unique participants based on participant_id
num_unique = df_participant['participant_id'].nunique()
print(f"Number of unique participants in df_participant: {num_unique}")
# Out:
# Number of duplicate rows: 0
# Number of unique participants in df_participant: 146

# %% [markdown]
# ### 1.2. Import background_survey_rows.csv file and drop duplicates

# %%
# Load the background_survey_rows.csv file
df_background = pd.read_csv(data_dir / 'background_survey_rows.csv', sep=',')

# Preview the dataset
df_background.head()
# Out:
#                                      id                        participant_id  \
# 0  8e250286-faa0-49b3-a1a4-1406c71e8a9c  fe4a79bb-642e-49d8-920a-a5f39035ffe3
# 1  f473691a-6c60-48ad-b6d8-915ba83c0787  151939c4-8aae-490b-92eb-c7d353a4a95c
# 2  1117999f-f29a-4dbc-9008-bf9fdc9c373a  151939c4-8aae-490b-92eb-c7d353a4a95c
# 3  9f1725f2-0e2b-46d6-a956-9081d0d37c6a  5c4cab45-aeba-4c55-a4c4-6b227b569474
# 4  aaa85758-33f8-457f-a614-5c70d54acb53  2bc7c0dd-423b-4c5c-bbff-fd89aa61ae8a
#
#                     submitted_at q1_age_group q2_gender          q3_education  \
# 0  2025-11-20 16:23:00.392222+00        18-24    Female  High school or below
# 1  2025-11-18 18:17:10.869409+00        35-44      Male       Master's degree
# 2  2025-11-18 18:17:05.061733+00        35-44      Male       Master's degree
# 3   2025-11-17 17:12:33.53304+00        18-24    Female     Bachelor's degree
# 4  2025-11-16 19:56:55.964839+00        25-34    Female       Master's degree
#
#   q4_employment q5_nationality q6_residence  q7_chatbot_familiarity  \
# 0       Student           Indo        China                       7
# 1      Employed        Iranian  Deutschland                       5
# 2      Employed        Iranian  Deutschland                       5
# 3       Student         German      Germany                       6
# 4      Employed       Pakistan     Pakistan                       5
#
#    q8_data_quality    q9_chatbot_usage             q10_search_tools
# 0                1  More than 10 times                       tiktok
# 1                1  More than 10 times                       Google
# 2                1  More than 10 times                      Goodgle
# 3                1  More than 10 times  Google, Amazon, BestSecret
# 4                6           3-5 times                     Pakistan

# %%
# Check for duplicates based on participant_id
duplicates = df_background[df_background.duplicated('participant_id', keep=False)]
print(f"Number of duplicate rows: {len(duplicates)}")
duplicates
# Out:
# Number of duplicate rows: 6
#                                       id  \
# 1   f473691a-6c60-48ad-b6d8-915ba83c0787
# 2   1117999f-f29a-4dbc-9008-bf9fdc9c373a
# 39  f9dff9c4-281b-4d28-b476-f45838b6015b
# 41  bc852c32-0a5e-402e-8907-59a541705f92
# 81  ad0376fa-1de0-491f-9b5a-f8a67a637074
# 82  9d4fb5ca-b80a-4285-b269-62567c628018
#
#                           participant_id                   submitted_at  \
# 1   151939c4-8aae-490b-92eb-c7d353a4a95c  2025-11-18 18:17:10.869409+00
# 2   151939c4-8aae-490b-92eb-c7d353a4a95c  2025-11-18 18:17:05.061733+00
# 39  b9fede00-231a-4c78-8324-6691b1533caf   2025-11-03 20:44:12.55231+00
# 41  b9fede00-231a-4c78-8324-6691b1533caf   2025-11-03 20:37:59.99122+00
# 81  5210feaa-5c2a-4444-b912-dc52d88c72c5  2025-10-27 13:12:33.301455+00
# 82  5210feaa-5c2a-4444-b912-dc52d88c72c5  2025-10-27 13:11:06.810905+00
#
#    q1_age_group q2_gender       q3_education q4_employment q5_nationality  \
# 1         35-44      Male    Master's degree      Employed        Iranian
# 2         35-44      Male    Master's degree      Employed        Iranian
# 39        18-24      Male  Bachelor's degree       Student        Israeli
# 41        18-24      Male  Bachelor's degree       Student        Israeli
# 81        18-24      Male    Master's degree       Student          Uzbek
# 82        18-24      Male    Master's degree       Student          Uzbek
#
#    q6_residence  q7_chatbot_familiarity  q8_data_quality    q9_chatbot_usage  \
# 1   Deutschland                       5                1  More than 10 times
# 2   Deutschland                       5                1  More than 10 times
# 39      Germany                       7                1  More than 10 times
# 41      Germany                       7                1  More than 10 times
# 81      Germany                       7                1  More than 10 times
# 82      Germany                       7                7  More than 10 times
#
#                                      q10_search_tools
# 1                                              Google
# 2                                             Goodgle
# 39  Amazon, chatgpt(to do research on the product)...
# 41  Amazon, chatgpt(to do research on the product)...
# 81                                             Google
# 82                                             Google

# %%
# Remove duplicate entries, keeping the latest occurrence

# Ensure submitted_at is in datetime format
df_background["submitted_at"] = pd.to_datetime(df_background["submitted_at"])

# Sort by participant_id and submitted_at (latest first)
df_background = df_background.sort_values(
    by=["participant_id", "submitted_at"], ascending=[True, False]
)

# Drop duplicates, keeping the first (which is now the latest due to sorting)
df_background = df_background.drop_duplicates(subset=["participant_id"], keep="first")

# Display the cleaned DataFrame
df_background.head()
# Out:
#                                       id  \
# 28  63be650a-84a9-4b98-8830-954148e95404
# 25  a45f022f-7003-4d4d-a109-8d1a65b2dd8f
# 31  7931724c-d393-4c73-97b0-4a4d1280f836
# 16  e398ecf5-22ce-41a3-9b6d-5931ef66081a
# 58  dd47d7ec-2686-4b62-b5b7-1a823e5d2e51
#
#                           participant_id                     submitted_at  \
# 28  05d6363b-4f7a-47b5-a91e-8f9a45d3bf07 2025-11-07 13:23:53.965032+00:00
# 25  090b95b5-f52a-4e45-8665-1cc819388638 2025-11-07 15:02:50.369086+00:00
# 31  0a4d4062-b718-43a8-a9be-95af5db59952 2025-11-07 12:41:14.251610+00:00
# 16  0ba4f0a8-673f-4054-80e0-690aaf497b51 2025-11-11 03:08:07.187937+00:00
# 58  0e8e279b-2364-4850-9f67-b682817f8378 2025-10-29 21:05:19.372164+00:00
#
#    q1_age_group q2_gender          q3_education q4_employment q5_nationality  \
# 28        18-24    Female       Master's degree       Student         German
# 25        18-24      Male     Bachelor's degree         Other         Syrian
# 31        25-34    Female       Master's degree       Student         Taiwan
# 16     Under 18    Female  High school or below       Student         Canada
# 58        25-34      Male       Master's degree      Employed       peruvian
#
#    q6_residence  q7_chatbot_familiarity  q8_data_quality    q9_chatbot_usage  \
# 28     Germany                        6                4          6-10 times
# 25      Germany                       6                1  More than 10 times
# 31      Germany                       6                1           3-5 times
# 16       Canada                       6                1          6-10 times
# 58      Germany                       6                1          6-10 times
#
#    q10_search_tools
# 28           Google
# 25          Chatgpt
# 31          Shoppee
# 16           Google
# 58           amazon

# %%
# Count unique participants based on participant_id after dropping duplicates
num_unique = df_background['participant_id'].nunique()
print(f"Number of unique participants in df_background: {num_unique}")
# Out:
# Number of unique participants in df_background: 88

# %%
# Drop unnecessary columns and rename for clarity (Preparing for Join datasets)

df_background = df_background.drop(columns=['id'])
df_background = df_background.rename(columns={'submitted_at': 'background_submitted_at'})

df_background.head()
# Out:
#                           participant_id          background_submitted_at  \
# 28  05d6363b-4f7a-47b5-a91e-8f9a45d3bf07 2025-11-07 13:23:53.965032+00:00
# 25  090b95b5-f52a-4e45-8665-1cc819388638 2025-11-07 15:02:50.369086+00:00
# 31  0a4d4062-b718-43a8-a9be-95af5db59952 2025-11-07 12:41:14.251610+00:00
# 16  0ba4f0a8-673f-4054-80e0-690aaf497b51 2025-11-11 03:08:07.187937+00:00
# 58  0e8e279b-2364-4850-9f67-b682817f8378 2025-10-29 21:05:19.372164+00:00
#
#    q1_age_group q2_gender          q3_education q4_employment q5_nationality  \
# 28        18-24    Female       Master's degree       Student         German
# 25        18-24      Male     Bachelor's degree         Other         Syrian
# 31        25-34    Female       Master's degree       Student         Taiwan
# 16     Under 18    Female  High school or below       Student         Canada
# 58        25-34      Male       Master's degree      Employed       peruvian
#
#    q6_residence  q7_chatbot_familiarity  q8_data_quality    q9_chatbot_usage  \
# 28     Germany                        6                4          6-10 times
# 25      Germany                       6                1  More than 10 times
# 31      Germany                       6                1           3-5 times
# 16       Canada                       6                1          6-10 times
# 58      Germany                       6                1          6-10 times
#
#    q10_search_tools
# 28           Google
# 25          Chatgpt
# 31          Shoppee
# 16           Google
# 58           amazon

# %% [markdown]
# ### 1.3. Import task_instruction_rows.csv file and drop duplicates

# %%
# Load the task_instruction_rows.csv file
df_instruction = pd.read_csv(data_dir / 'task_instruction_rows.csv', sep=',')

# Preview the dataset
df_instruction.head()
# Out:
#                                      id                        participant_id  \
# 0  fe2704b0-30f1-4a67-91c2-a034af66c2d7  fe4a79bb-642e-49d8-920a-a5f39035ffe3
# 1  ae9c09f8-42eb-4e70-b0aa-09e151415f4f  151939c4-8aae-490b-92eb-c7d353a4a95c
# 2  08f476f3-d31b-451b-b7ce-04fe6f787198  5c4cab45-aeba-4c55-a4c4-6b227b569474
# 3  f55c5695-d676-4083-90a7-e1da75e2ee41  2bc7c0dd-423b-4c5c-bbff-fd89aa61ae8a
# 4  95ebee41-fbf7-4099-85e2-f9f566bf3c1a  e2f70344-8588-468c-9dc2-8c2993f5b6c9
#
#   q11_budget                   completed_at
# 0  Over €800   2025-11-20 16:23:08.15456+00
# 1   €600-799  2025-11-18 18:17:25.690481+00
# 2   €450-599  2025-11-17 17:13:24.879267+00
# 3   €150-299  2025-11-16 19:57:03.504302+00
# 4   €600-799  2025-11-15 23:30:13.982834+00

# %%
# Check for duplicates based on participant_id
duplicates = df_instruction[df_instruction.duplicated('participant_id', keep=False)]
print(f"Number of duplicate rows: {len(duplicates)}")
duplicates
# Out:
# Number of duplicate rows: 24
#                                       id  \
# 14  c492b78d-6067-4071-a5ac-49009160afe2
# 15  89d956a8-1484-4e02-9879-a6b0a14c5a9d
# 16  c2dd06be-b062-49ee-a33d-9dbd55e1288d
# 17  bb5c8078-0d87-4403-b58b-4b31131549a2
# 18  d4d8817b-b313-4ea9-b637-5c56a0124424
# 24  c9616b47-61cc-4383-9be0-b63f534a98e0
# 25  a96c87e4-b632-42aa-b532-5944a9d8ade0
# 26  bb879b17-ac13-43d9-b3b4-6b6c1155d870
# 27  e1981cab-e2cf-4c03-9165-663d7a511042
# 28  8edb32b1-5fa6-4d21-88f6-d5f4097d8e34
# 33  ccf8fa71-f5f6-4864-a2cc-ce7cfa6b0966
# 34  258858a6-cf9b-4642-8472-9bc8b204e3ec
# 39  21d7be2f-d2a0-448e-81cc-fcc696653485
# 40  b5c728b0-27ed-4691-8663-ff8fd1f04548
# 41  7b9e0ad8-d727-4a0c-aa20-159d837dce1a
# 44  3734f201-7525-4c9c-8cc7-444aef5b18c0
# 45  fd14eacc-d5e7-4c30-959d-e0d9bfa0a09c
# 47  49effd68-d208-460c-a3a6-f71759ae2668
# 65  039f313a-b918-4ac4-92cc-07de39925d5a
# 66  14ee629e-3bd9-442d-9a24-ea7cbe33a816
# 82  e8ddc196-1d83-4494-a908-a235cfc6fced
# 83  93e18b9b-f3b8-42b4-8c3b-befe5218d7d5
# 89  cc7a9ad6-1b00-432d-9390-197fde919296
# 90  670336f5-2098-4b4e-a9ca-d1b8534c367b
#
#                           participant_id q11_budget  \
# 14  0ba4f0a8-673f-4054-80e0-690aaf497b51   €450-599
# 15  0ba4f0a8-673f-4054-80e0-690aaf497b51   €450-599
# 16  0ba4f0a8-673f-4054-80e0-690aaf497b51   €450-599
# 17  548569b2-6aeb-4403-9dfe-4b84cd9cbf25   €150-299
# 18  548569b2-6aeb-4403-9dfe-4b84cd9cbf25   €150-299
# 24  2c298a5e-7070-4fd7-a6fe-ff3907029e8c   €600-799
# 25  2c298a5e-7070-4fd7-a6fe-ff3907029e8c   €600-799
# 26  21121fd2-00ef-4b2a-974f-823f26f3f7fd  Over €800
# 27  21121fd2-00ef-4b2a-974f-823f26f3f7fd  Over €800
# 28  21121fd2-00ef-4b2a-974f-823f26f3f7fd  Over €800
# 33  95a96e83-18a8-47ad-919e-faee2ccf6d1d   €300-449
# 34  95a96e83-18a8-47ad-919e-faee2ccf6d1d   €300-449
# 39  25b4d886-f5c7-461e-864f-52ea2e3c01b7   €450-599
# 40  25b4d886-f5c7-461e-864f-52ea2e3c01b7   €450-599
# 41  25b4d886-f5c7-461e-864f-52ea2e3c01b7   €450-599
# 44  b9fede00-231a-4c78-8324-6691b1533caf  Over €800
# 45  b9fede00-231a-4c78-8324-6691b1533caf  Over €800
# 47  b9fede00-231a-4c78-8324-6691b1533caf   €300-449
# 65  0e8e279b-2364-4850-9f67-b682817f8378   €150-299
# 66  0e8e279b-2364-4850-9f67-b682817f8378   €150-299
# 82  193a0563-b869-4bbe-aa9e-d81bacf59a3e   €600-799
# 83  193a0563-b869-4bbe-aa9e-d81bacf59a3e   €600-799
# 89  b43e4bd1-d8cb-4284-9079-1ff9f84146b4   €300-449
# 90  b43e4bd1-d8cb-4284-9079-1ff9f84146b4   €300-449
#
#                      completed_at
# 14   2025-11-11 03:10:00.06837+00
# 15  2025-11-11 03:08:52.053916+00
# 16  2025-11-11 03:08:34.307695+00
# 17  2025-11-10 22:31:14.471017+00
# 18   2025-11-10 22:30:49.44762+00
# 24  2025-11-09 12:17:20.020105+00
# 25  2025-11-09 12:16:59.691731+00
# 26  2025-11-08 13:31:16.716906+00
# 27  2025-11-08 13:28:24.631875+00
# 28  2025-11-08 13:25:23.088201+00
# 33  2025-11-07 13:07:47.966955+00
# 34  2025-11-07 13:07:36.157346+00
# 39  2025-11-04 16:18:36.092125+00
# 40  2025-11-04 16:15:39.765042+00
# 41  2025-11-04 16:14:38.945686+00
# 44  2025-11-03 20:44:13.510166+00
# 45  2025-11-03 20:41:24.129924+00
# 47  2025-11-03 20:38:18.842596+00
# 65  2025-10-29 21:09:38.500944+00
# 66  2025-10-29 21:06:09.400479+00
# 82  2025-10-27 16:21:43.600933+00
# 83  2025-10-27 16:21:04.730274+00
# 89  2025-10-27 12:32:58.905316+00
# 90  2025-10-27 12:31:58.680969+00

# %%
# Remove duplicate entries, keeping the latest occurrence

# Ensure completed_at is in datetime format
df_instruction["completed_at"] = pd.to_datetime(df_instruction["completed_at"])

# Sort by participant_id and completed_at (latest first)
df_instruction = df_instruction.sort_values(
    by=["participant_id", "completed_at"], ascending=[True, False]
)

# Drop duplicates, keeping the first (which is now the latest due to sorting)
df_instruction = df_instruction.drop_duplicates(subset=["participant_id"], keep="first")

# Display the cleaned DataFrame
df_instruction.head()
# Out:
#                                       id  \
# 29  fd76061d-d067-4517-9ef2-4dfe203e4265
# 14  c492b78d-6067-4071-a5ac-49009160afe2
# 65  039f313a-b918-4ac4-92cc-07de39925d5a
# 56  0c05947a-f4bb-4572-beec-07e10df36231
# 76  36e55ef5-b68c-467b-add8-e27caf317e46
#
#                           participant_id q11_budget  \
# 29  090b95b5-f52a-4e45-8665-1cc819388638   €450-599
# 14  0ba4f0a8-673f-4054-80e0-690aaf497b51   €450-599
# 65  0e8e279b-2364-4850-9f67-b682817f8378   €150-299
# 56  145a5e3a-5d68-4457-9cc1-eaffd6662734   €300-449
# 76  14ff50af-72a9-4095-a217-88246441fe94  Over €800
#
#                        completed_at
# 29 2025-11-07 15:05:24.138584+00:00
# 14 2025-11-11 03:10:00.068370+00:00
# 65 2025-10-29 21:09:38.500944+00:00
# 56 2025-10-31 14:01:24.763496+00:00
# 76 2025-10-29 09:51:43.515248+00:00

# %%
# Count unique participants based on participant_id after dropping duplicates
num_unique = df_instruction['participant_id'].nunique()
print(f"Number of unique participants in df_instruction: {num_unique}")
# Out:
# Number of unique participants in df_instruction: 82

# %%
# Drop unnecessary columns and rename for clarity (Preparing for Join datasets)

df_instruction = df_instruction.drop(columns=['id'])
df_instruction = df_instruction.rename(columns={'completed_at': 'instruction_submitted_at'})

df_instruction.head()
# Out:
#                           participant_id q11_budget  \
# 29  090b95b5-f52a-4e45-8665-1cc819388638   €450-599
# 14  0ba4f0a8-673f-4054-80e0-690aaf497b51   €450-599
# 65  0e8e279b-2364-4850-9f67-b682817f8378   €150-299
# 56  145a5e3a-5d68-4457-9cc1-eaffd6662734   €300-449
# 76  14ff50af-72a9-4095-a217-88246441fe94  Over €800
#
#            instruction_submitted_at
# 29 2025-11-07 15:05:24.138584+00:00
# 14 2025-11-11 03:10:00.068370+00:00
# 65 2025-10-29 21:09:38.500944+00:00
# 56 2025-10-31 14:01:24.763496+00:00
# 76 2025-10-29 09:51:43.515248+00:00

# %% [markdown]
# ### 2.1. Import search_logs_rows.csv file and drop duplicates

# %%
# Load the search_logs_rows.csv file
df_logs = pd.read_csv(data_dir / 'search_logs_rows.csv', sep=',')

# Preview the dataset
df_logs.head()
# Out:
#                                      id                        participant_id  \
# 0  3db2a856-67c0-47b6-83c8-35a3833b4ea6  fe4a79bb-642e-49d8-920a-a5f39035ffe3
# 1  556e0853-4a47-4a52-a5a5-c4eb472b2dd0  fe4a79bb-642e-49d8-920a-a5f39035ffe3
# 2  9c4f56b0-c117-4cd0-ad7a-acf865bb6aa1  151939c4-8aae-490b-92eb-c7d353a4a95c
# 3  a71bc03e-2066-47fe-adf9-a6d99fc96bb3  151939c4-8aae-490b-92eb-c7d353a4a95c
# 4  42b495a7-0222-4644-b9e1-c4d315652753  151939c4-8aae-490b-92eb-c7d353a4a95c
#
#                                               prompt  \
# 0                      in euros? iphone 16 pro price
# 1  i am a gen z that is currently in the apple ec...
# 2  I meant which of the phones you listed above y...
# 3            all in all, which one do you recommend?
# 4  compare the batteries, which one do you recome...
#
#                                             response  \
# 0  The official starting price for the **iPhone 1...
# 1  Based on your situation as a Gen Z user in the...
# 2  Based on the latest expert reviews, the **Sams...
# 3  To provide a recommendation, I need to know wh...
# 4  For the longest battery life and minimal charg...
#
#                        logged_at            query_start_time  \
# 0  2025-11-20 16:27:45.421413+00  2025-11-20 16:27:28.282+00
# 1  2025-11-20 16:26:36.976967+00  2025-11-20 16:23:40.106+00
# 2  2025-11-18 18:22:14.869105+00  2025-11-18 18:21:40.219+00
# 3  2025-11-18 18:21:31.038379+00  2025-11-18 18:21:16.929+00
# 4  2025-11-18 18:20:58.632253+00  2025-11-18 18:20:17.925+00
#
#             query_submit_time  query_duration_ms  query_sequence_number
# 0   2025-11-20 16:27:37.91+00             9628.0                      2
# 1  2025-11-20 16:26:25.248+00           165142.0                      1
# 2  2025-11-18 18:22:00.949+00            20730.0                      6
# 3  2025-11-18 18:21:26.716+00             9787.0                      5
# 4  2025-11-18 18:20:39.321+00            21396.0                      4

# %%
# Check for duplicates in df_logs based on participant_id and prompt
duplicates = df_logs[df_logs.duplicated(['participant_id', 'prompt'], keep=False)]
print(f"Number of duplicate rows: {len(duplicates)}")
duplicates.head()
# Out:
# Number of duplicate rows: 2
#                                        id  \
# 142  b1edddcc-bec3-4409-91f4-eac09fa1d1d6
# 143  561a7512-524b-4930-b1a2-3074f4236688
#
#                            participant_id  \
# 142  193a0563-b869-4bbe-aa9e-d81bacf59a3e
# 143  193a0563-b869-4bbe-aa9e-d81bacf59a3e
#
#                                                 prompt  \
# 142  Search for smartphones that have an excellent ...
# 143  Search for smartphones that have an excellent ...
#
#                                               response  \
# 142  Looking at smartphones with excellent price-to...
# 143  For a smartphone with an excellent price-to-qu...
#
#                          logged_at            query_start_time  \
# 142  2025-10-27 16:25:11.095845+00  2025-10-27 16:24:43.276+00
# 143  2025-10-27 16:24:28.648307+00  2025-10-27 16:21:46.082+00
#
#               query_submit_time  query_duration_ms  query_sequence_number
# 142  2025-10-27 16:24:47.046+00             3770.0                      2
# 143    2025-10-27 16:24:11.2+00           145118.0                      1

# %%
# Remove duplicate entries in df_logs, keeping the latest occurrence based on query_submit_time

# Ensure query_submit_time is in datetime format
df_logs["query_submit_time"] = pd.to_datetime(df_logs["query_submit_time"])

# Sort by participant_id, prompt and query_submit_time (latest first)
df_logs = df_logs.sort_values(by=["participant_id", "prompt", "query_submit_time"], ascending=[True, True, False])

# Drop duplicates, keeping the first (which is now the latest due to sorting)
df_logs = df_logs.drop_duplicates(subset=["participant_id", "prompt"], keep="first")

# Display the cleaned DataFrame
df_logs.head()
# Out:
#                                       id  \
# 57  081f5514-6b20-4531-8f53-241b96ddc6e1
# 37  74c4060e-a301-45c1-a880-5109fcb9c036
# 33  cf51fc28-d3f0-46d2-a9d0-da661e0c7391
# 34  ed47f17f-7dc1-42a7-949c-f6a64bd56d0c
# 35  8b17b23e-b61b-461e-9a01-55edf53e693c
#
#                           participant_id  \
# 57  090b95b5-f52a-4e45-8665-1cc819388638
# 37  0ba4f0a8-673f-4054-80e0-690aaf497b51
# 33  0ba4f0a8-673f-4054-80e0-690aaf497b51
# 34  0ba4f0a8-673f-4054-80e0-690aaf497b51
# 35  0ba4f0a8-673f-4054-80e0-690aaf497b51
#
#                                                prompt  \
# 57  What is a realistic phone when it comes to cos...
# 37  What phones are currently available on the mar...
# 33                            give me prices in euros
# 34  give the lowest price you can find for the app...
# 35  no, i mean tell me about (for the phones you m...
#
#                                              response  \
# 57  A realistic phone with the best cost-to-qualit...
# 37  Several **excellent budget and mid-range smart...
# 33  To provide **prices in euros**, you need to co...
# 34  The **lowest price for a new, unlocked Apple i...
# 35  Based on the latest expert rankings and review...
#
#                         logged_at            query_start_time  \
# 57  2025-11-07 15:08:07.503559+00  2025-11-07 15:05:33.382+00
# 37  2025-11-11 03:09:30.955579+00  2025-11-11 03:08:53.203+00
# 33  2025-11-11 03:16:25.604953+00  2025-11-11 03:16:17.415+00
# 34  2025-11-11 03:14:46.851105+00  2025-11-11 03:14:19.384+00
# 35  2025-11-11 03:12:34.977885+00  2025-11-11 03:11:37.266+00
#
#                   query_submit_time  query_duration_ms  query_sequence_number
# 57 2025-11-07 15:07:50.895000+00:00           137513.0                      1
# 37 2025-11-11 03:09:17.501000+00:00            24298.0                      1
# 33 2025-11-11 03:16:19.917000+00:00             2502.0                      5
# 34 2025-11-11 03:14:40.420000+00:00            21036.0                      4
# 35 2025-11-11 03:12:16.250000+00:00            38984.0                      3

# %%
# Count unique participants based on participant_id after dropping duplicates
num_unique = df_logs['participant_id'].nunique()
print(f"Number of unique participants in df_logs: {num_unique}")
# Out:
# Number of unique participants in df_logs: 59

# %% [markdown]
# ### 2.2. Import search_clicks_rows.csv file and check unique participats

# %%
# Load the search_clicks_rows.csv file
df_clicks = pd.read_csv(data_dir / 'search_clicks_rows.csv', sep=',')

# Preview the dataset
df_clicks.head()
# Out:
#                                      id                        participant_id  \
# 0  91069fed-a389-4d0e-bf76-6b556aeef03c  151939c4-8aae-490b-92eb-c7d353a4a95c
# 1  60f5d232-2c51-456b-afa5-f3f0bcb68231  5c4cab45-aeba-4c55-a4c4-6b227b569474
# 2  84b7ab19-cd0f-4f73-9fb8-f17b85a2ab62  233c60f2-995c-4779-970d-dbbbd7c1da52
# 3  a700f17d-f80e-4f54-8ab4-ee62df4f58c8  0ba4f0a8-673f-4054-80e0-690aaf497b51
# 4  709ed9ce-9852-4a3e-a9dd-70e74b9d0f34  548569b2-6aeb-4403-9dfe-4b84cd9cbf25
#
#    prompt_index                                                url  \
# 0             1  https://www.accio.com/business/best-selling-sm...
# 1             3              https://www.apple.com/shop/buy-iphone
# 2             3  https://www.samsung.com/de/smartphones/galaxy-...
# 3             4  https://www.apple.com/shop/buy-iphone/iphone-1...
# 4             1  https://www.notebookcheck.net/Ranking-Best-sma...
#
#                       clicked_at
# 0  2025-11-18 18:23:34.693101+00
# 1    2025-11-17 17:16:32.5906+00
# 2  2025-11-14 23:22:22.601176+00
# 3  2025-11-11 03:17:08.006738+00
# 4  2025-11-10 22:33:40.496327+00

# %%
# Count unique participants in df_clicks based on participant_id

unique_participants_df_clicks = df_clicks['participant_id'].nunique()
print(f"Number of unique participants in df_clicks: {unique_participants_df_clicks}")
# Out:
# Number of unique participants in df_clicks: 21

# %% [markdown]
# ### 2.3. Import session_timing_rows.csv file and check unique participats

# %%
# Load the session_timing_rows.csv file
df_timing = pd.read_csv(data_dir / 'session_timing_rows.csv', sep=',')

# Preview the dataset
df_timing.head()
# Out:
#                                      id                        participant_id  \
# 0  fd78bd23-3cf7-421e-bdeb-c14a5bfb4b1f  fe4a79bb-642e-49d8-920a-a5f39035ffe3
# 1  20b08b71-f6e3-45ca-a318-b2a6881d9e26  fe4a79bb-642e-49d8-920a-a5f39035ffe3
# 2  2a313e5e-4e25-4be1-94c9-ed83ebda8ecc  fe4a79bb-642e-49d8-920a-a5f39035ffe3
# 3  629db404-f4e6-4ee9-98d1-419673b41937  fe4a79bb-642e-49d8-920a-a5f39035ffe3
# 4  20479efd-6636-48f9-83f4-e0923213ee76  fe4a79bb-642e-49d8-920a-a5f39035ffe3
#
#            session_start_time            session_end_time  \
# 0  2025-11-20 16:28:00.829+00   2025-11-20 16:28:10.12+00
# 1  2025-11-20 16:27:27.603+00  2025-11-20 16:27:50.572+00
# 2  2025-11-20 16:23:39.474+00  2025-11-20 16:26:48.525+00
# 3  2025-11-20 16:23:08.415+00   2025-11-20 16:23:30.53+00
# 4  2025-11-20 16:23:08.415+00  2025-11-20 16:23:29.747+00
#
#    session_duration_ms              record_created_at
# 0               9291.0  2025-11-20 16:28:02.231156+00
# 1              22969.0  2025-11-20 16:27:29.591439+00
# 2             189051.0  2025-11-20 16:23:41.070405+00
# 3              22115.0  2025-11-20 16:23:31.852449+00
# 4              21332.0  2025-11-20 16:23:09.530918+00

# %%
# Count unique participants in df_timing based on participant_id

unique_participants_df_timing = df_timing['participant_id'].nunique()
print(f"Number of unique participants in df_timing: {unique_participants_df_timing}")
# Out:
# Number of unique participants in df_timing: 83

# %% [markdown]
# ### 1.4. Import search_results_rows.csv file and drop duplicates

# %%
# Load the search_results_rows.csv file
df_results = pd.read_csv(data_dir / 'search_results_rows.csv', sep=',')

# Preview the dataset
df_results.head()
# Out:
#                                      id                        participant_id  \
# 0  d69f5fd2-8647-446d-bf5f-d7d4d95bd5bd  fe4a79bb-642e-49d8-920a-a5f39035ffe3
# 1  e08ef69c-e2cf-4ca7-b1bd-8ba6c6969286  151939c4-8aae-490b-92eb-c7d353a4a95c
# 2  61a8b287-daa2-4f2a-81fb-8b986b5846bf  e2f70344-8588-468c-9dc2-8c2993f5b6c9
# 3  cf915025-bcc2-4601-a95c-3c100486db9f  82e40cf7-aadd-46a9-a1b5-f68aed30f6af
# 4  6779e0a5-d521-430b-92a4-c5a1e2399b09  88584cfe-a550-4209-a1f3-be628bb2647b
#
#                     submitted_at   q12_brand_model      q13_storage  \
# 0  2025-11-20 16:28:44.825722+00     iphone 16 pro              256
# 1  2025-11-18 18:24:07.194885+00  Galaxy S25 Ultra              256
# 2  2025-11-15 23:33:02.200087+00         iphone 16  i dont remember
# 3  2025-11-15 06:41:10.904399+00     Iphon 15 plus              NaN
# 4  2025-11-13 16:33:03.325266+00     Iphone 17 pro              128
#
#        q14_color q15_price                                        q16_website  \
# 0            NaN     1,359     https://fr.mobileinto.com/Apple-iPhone-16-Pro/
# 1  not mentioned       740  https://www.accio.com/business/best-selling-sm...
# 2          black       600                             i dont have it anymore
# 3            NaN       430  https://www.xfinity.com/mobile/shop/phone/ipho...
# 4          Black      1200  https://www.rebuy.fr/acheter/mobile/apple/gene...
#
#    q17_price_importance                             q18_important_features
# 0                     3                     ["Software support & updates"]
# 1                     5  ["Battery life/ fast charging","Display Qualit...
# 2                     7  ["Battery life/ fast charging","Storage capaci...
# 3                     4  ["Performance/ speed","Storage capacity","Disp...
# 4                     3  ["Battery life/ fast charging","Camera quality...

# %%
# Check for duplicates based on participant_id

duplicates = df_results[df_results.duplicated('participant_id', keep=False)]
print(f"Number of duplicate rows: {len(duplicates)}")
duplicates
# Out:
# Number of duplicate rows: 7
#                                       id  \
# 26  2cb55638-c38a-468f-a5f0-1447ca89cbc9
# 27  c5c13cbf-19b7-4655-81e1-176af095c033
# 28  8f493290-3008-461f-b6a4-88eb783ba000
# 30  4684ef91-5d38-4b16-9757-13a94cd8c28d
# 31  91acb4ca-bc0f-4265-94bb-706ee697da4f
# 44  0ab143af-b624-4008-b73c-27facfd89550
# 45  ac98e705-b2c1-4c6f-bc01-989b7e217a64
#
#                           participant_id                   submitted_at  \
# 26  1cde5bc6-87ef-4a39-87da-3e93c51cfffa  2025-11-03 21:05:01.499197+00
# 27  1cde5bc6-87ef-4a39-87da-3e93c51cfffa  2025-11-03 21:02:18.638279+00
# 28  1cde5bc6-87ef-4a39-87da-3e93c51cfffa  2025-11-03 20:59:39.161288+00
# 30  b9fede00-231a-4c78-8324-6691b1533caf  2025-11-03 20:44:16.476432+00
# 31  b9fede00-231a-4c78-8324-6691b1533caf  2025-11-03 20:41:28.783288+00
# 44  a9ea56d9-8f16-4706-8730-7759a9ae43ff  2025-10-30 18:05:07.809727+00
# 45  a9ea56d9-8f16-4706-8730-7759a9ae43ff  2025-10-30 18:04:54.328411+00
#
#              q12_brand_model q13_storage q14_color q15_price  \
# 26               Samsung S25         256      blue       639
# 27               Samsung S25         256      blue       639
# 28               Samsung S25         256      blue       639
# 30  Samsung galaxy S25 Ultra       512GB     Black   859 EUR
# 31  Samsung galaxy S25 Ultra       512GB     Black   859 EUR
# 44                 Iphone 17       256GB    Purple      €620
# 45                 Iphone 17       256GB    Purple      €620
#
#                                           q16_website  q17_price_importance  \
# 26  https://www.kaufland.de/product/524765710/?kwd...                     5
# 27  https://www.kaufland.de/product/524765710/?kwd...                     5
# 28  https://www.kaufland.de/product/524765710/?kwd...                     5
# 30  https://www.backmarket.de/de-de/p/samsung-gb/f...                     2
# 31  https://www.backmarket.de/de-de/p/samsung-gb/f...                     2
# 44  https://lp.pinduoduo.com/poros/h5?ads_channel=...                     5
# 45  https://lp.pinduoduo.com/poros/h5?ads_channel=...                     5
#
#                                q18_important_features
# 26  ["Camera quality","Storage capacity","Software...
# 27  ["Camera quality","Storage capacity","Software...
# 28  ["Camera quality","Storage capacity","Software...
# 30  ["Battery life/ fast charging","Performance/ s...
# 31  ["Battery life/ fast charging","Performance/ s...
# 44  ["Display Quality","Software support & updates...
# 45  ["Display Quality","Software support & updates...

# %%
# Remove duplicate entries, keeping the latest occurrence

# Ensure completed_at is in datetime format
df_results["submitted_at"] = pd.to_datetime(df_results["submitted_at"])

# Sort by participant_id and submitted_at (latest first)
df_results = df_results.sort_values(
    by=["participant_id", "submitted_at"], ascending=[True, False]
)

# Drop duplicates, keeping the first (which is now the latest due to sorting)
df_results = df_results.drop_duplicates(subset=["participant_id"], keep="first")

# Display the cleaned DataFrame
df_results.head()
# Out:
#                                       id  \
# 18  3abfcc65-1106-424d-941a-f5832008e460
# 11  60c8394a-04aa-421e-ba59-0835ef943d9c
# 47  b859c304-2ba8-46dd-95a8-dc384f0690eb
# 39  35149535-51ac-4a4f-b081-17000b345b61
# 1   e08ef69c-e2cf-4ca7-b1bd-8ba6c6969286
#
#                           participant_id                     submitted_at  \
# 18  090b95b5-f52a-4e45-8665-1cc819388638 2025-11-07 15:09:47.643924+00:00
# 11  0ba4f0a8-673f-4054-80e0-690aaf497b51 2025-11-11 03:17:49.786245+00:00
# 47  0e8e279b-2364-4850-9f67-b682817f8378 2025-10-29 21:40:57.407264+00:00
# 39  145a5e3a-5d68-4457-9cc1-eaffd6662734 2025-10-31 14:13:37.345332+00:00
# 1   151939c4-8aae-490b-92eb-c7d353a4a95c 2025-11-18 18:24:07.194885+00:00
#
#             q12_brand_model q13_storage      q14_color q15_price  \
# 18          Google pixel 9a         NaN            NaN       NaN
# 11  Apple iPhone 17 Pro Max         NaN            NaN      €801
# 47       Xiaomi Poco X7 Pro      512 GB          Black       299
# 39          Google Pixel 9a     128 GB       Porcelain       399
# 1          Galaxy S25 Ultra         256  not mentioned       740
#
#                                           q16_website  q17_price_importance  \
# 18                                                NaN                     6
# 11  https://www.apple.com/shop/buy-iphone/iphone-1...                     3
# 47              https://www.ebay.com/itm/326414840756                     4
# 39  https://www.phonearena.com/news/pixel-9a-still...                     4
# 1   https://www.accio.com/business/best-selling-sm...                     5
#
#                                q18_important_features
# 18  ["Battery life/ fast charging","Display Qualit...
# 11            ["Performance/ speed","Camera quality"]
# 47  ["Battery life/ fast charging","Camera quality...
# 39  ["Battery life/ fast charging","Camera quality...
# 1   ["Battery life/ fast charging","Display Qualit...

# %%
# Count unique participants based on participant_id after dropping duplicates
num_unique = df_results['participant_id'].nunique()
print(f"Number of unique participants in df_results: {num_unique}")
# Out:
# Number of unique participants in df_results: 60

# %%
# Drop unnecessary columns and rename for clarity (Preparing for Join datasets)

df_results = df_results.drop(columns=['id'])
df_results = df_results.rename(columns={'submitted_at': 'results_submitted_at'})

df_results.head()
# Out:
#                           participant_id             results_submitted_at  \
# 18  090b95b5-f52a-4e45-8665-1cc819388638 2025-11-07 15:09:47.643924+00:00
# 11  0ba4f0a8-673f-4054-80e0-690aaf497b51 2025-11-11 03:17:49.786245+00:00
# 47  0e8e279b-2364-4850-9f67-b682817f8378 2025-10-29 21:40:57.407264+00:00
# 39  145a5e3a-5d68-4457-9cc1-eaffd6662734 2025-10-31 14:13:37.345332+00:00
# 1   151939c4-8aae-490b-92eb-c7d353a4a95c 2025-11-18 18:24:07.194885+00:00
#
#             q12_brand_model q13_storage      q14_color q15_price  \
# 18          Google pixel 9a         NaN            NaN       NaN
# 11  Apple iPhone 17 Pro Max         NaN            NaN      €801
# 47       Xiaomi Poco X7 Pro      512 GB          Black       299
# 39          Google Pixel 9a     128 GB       Porcelain       399
# 1          Galaxy S25 Ultra         256  not mentioned       740
#
#                                           q16_website  q17_price_importance  \
# 18                                                NaN                     6
# 11  https://www.apple.com/shop/buy-iphone/iphone-1...                     3
# 47              https://www.ebay.com/itm/326414840756                     4
# 39  https://www.phonearena.com/news/pixel-9a-still...                     4
# 1   https://www.accio.com/business/best-selling-sm...                     5
#
#                                q18_important_features
# 18  ["Battery life/ fast charging","Display Qualit...
# 11            ["Performance/ speed","Camera quality"]
# 47  ["Battery life/ fast charging","Camera quality...
# 39  ["Battery life/ fast charging","Camera quality...
# 1   ["Battery life/ fast charging","Display Qualit...

# %% [markdown]
# ### 1.5. Import post_task_survey_rows.csv file and drop duplicates

# %%
# Load the post_task_survey_rows.csv file
df_postsurvey = pd.read_csv(data_dir / 'post_task_survey_rows.csv', sep=',')

# Preview the dataset
df_postsurvey.head()
# Out:
#                                      id                        participant_id  \
# 0  aebb3361-0bba-46d2-9622-2785acb7c8b3  fe4a79bb-642e-49d8-920a-a5f39035ffe3
# 1  b74b4dc8-b7b2-4816-965d-cc8ed24df3fc  151939c4-8aae-490b-92eb-c7d353a4a95c
# 2  0697e7ca-d908-49e5-be65-18ade5105ddd  e2f70344-8588-468c-9dc2-8c2993f5b6c9
# 3  d651caff-2c77-4613-b3c2-a3132a7fdf1d  82e40cf7-aadd-46a9-a1b5-f68aed30f6af
# 4  efc9e4af-24aa-4025-87c4-d93cc6113a01  233c60f2-995c-4779-970d-dbbbd7c1da52
#
#                     submitted_at  q38_attention         q41_duration  \
# 0  2025-11-20 16:30:12.966171+00              3  Less than 2 minutes
# 1  2025-11-18 18:27:05.061232+00              3         6–10 minutes
# 2  2025-11-15 23:36:06.862026+00              3          3–5 minutes
# 3   2025-11-15 06:42:42.68637+00              3  Less than 2 minutes
# 4   2025-11-14 23:28:53.32169+00              3          3–5 minutes
#
#                                         q42_comments  \
# 0                                                yea
# 1  I might if the information is provided in a la...
# 2                               it was a little slow
# 3  No, I felt like it was not that complicated, b...
# 4  Yes, helps save time and provides me with rele...
#
#                               q39_contradictory_info  q19_task_easy  \
# 0                                          ["Other"]              6
# 1              ["I did not find any contradictions"]              5
# 2  ["I trusted the first response I got","I relie...              6
# 3             ["I trusted the first response I got"]              2
# 4  ["I chose the response that seemed most detail...              7
#
#    q20_task_quick  q21_task_familiar  ...  q29_tool_easier_task  \
# 0               4                  6  ...                     6
# 1               5                  5  ...                     6
# 2               5                  7  ...                     5
# 3               5                  3  ...                     4
# 4               7                  3  ...                     7
#
#    q30_tool_useful  q31_tool_too_much_info  q32_tool_difficult_focus  \
# 0                5                       7                         6
# 1                7                       6                         4
# 2                5                       6                         5
# 3                5                       4                         4
# 4                7                       7                         7
#
#    q33_results_accurate  q34_results_trust  q35_results_complete  \
# 0                     7                  5                     5
# 1                     4                  5                     5
# 2                     3                  4                     4
# 3                     5                  6                     3
# 4                     6                  6                     6
#
#    q36_results_relevant  q37_results_useful  q40_purchase_likelihood
# 0                     6                   7                        2
# 1                     5                   5                        6
# 2                     6                   3                        5
# 3                     4                   3                        6
# 4                     6                   6                        5
#
# [5 rows x 27 columns]

# %%
# Check for duplicates based on participant_id

duplicates = df_postsurvey[df_postsurvey.duplicated('participant_id', keep=False)]
print(f"Number of duplicate rows: {len(duplicates)}")
duplicates
# Out:
# Number of duplicate rows: 0
# Empty DataFrame
# Columns: [id, participant_id, submitted_at, q38_attention, q41_duration, q42_comments, q39_contradictory_info, q19_task_easy, q20_task_quick, q21_task_familiar, q22_tool_reliable, q23_tool_practical, q24_tool_like, q25_tool_easy_use, q26_tool_clear, q27_tool_control, q28_tool_info_provided, q29_tool_easier_task, q30_tool_useful, q31_tool_too_much_info, q32_tool_difficult_focus, q33_results_accurate, q34_results_trust, q35_results_complete, q36_results_relevant, q37_results_useful, q40_purchase_likelihood]
# Index: []
#
# [0 rows x 27 columns]

# %%
# Drop unnecessary columns and rename for clarity (Preparing for Join datasets)

df_postsurvey = df_postsurvey.drop(columns=['id'])
df_postsurvey = df_postsurvey.rename(columns={'submitted_at': 'postsurvey_submitted_at'})

df_postsurvey.head()
# Out:
#                          participant_id        postsurvey_submitted_at  \
# 0  fe4a79bb-642e-49d8-920a-a5f39035ffe3  2025-11-20 16:30:12.966171+00
# 1  151939c4-8aae-490b-92eb-c7d353a4a95c  2025-11-18 18:27:05.061232+00
# 2  e2f70344-8588-468c-9dc2-8c2993f5b6c9  2025-11-15 23:36:06.862026+00
# 3  82e40cf7-aadd-46a9-a1b5-f68aed30f6af   2025-11-15 06:42:42.68637+00
# 4  233c60f2-995c-4779-970d-dbbbd7c1da52   2025-11-14 23:28:53.32169+00
#
#    q38_attention         q41_duration  \
# 0              3  Less than 2 minutes
# 1              3         6–10 minutes
# 2              3          3–5 minutes
# 3              3  Less than 2 minutes
# 4              3          3–5 minutes
#
#                                         q42_comments  \
# 0                                                yea
# 1  I might if the information is provided in a la...
# 2                               it was a little slow
# 3  No, I felt like it was not that complicated, b...
# 4  Yes, helps save time and provides me with rele...
#
#                               q39_contradictory_info  q19_task_easy  \
# 0                                          ["Other"]              6
# 1              ["I did not find any contradictions"]              5
# 2  ["I trusted the first response I got","I relie...              6
# 3             ["I trusted the first response I got"]              2
# 4  ["I chose the response that seemed most detail...              7
#
#    q20_task_quick  q21_task_familiar  q22_tool_reliable  ...  \
# 0               4                  6                  6  ...
# 1               5                  5                  5  ...
# 2               5                  7                  3  ...
# 3               5                  3                  5  ...
# 4               7                  3                  6  ...
#
#    q29_tool_easier_task  q30_tool_useful  q31_tool_too_much_info  \
# 0                     6                5                       7
# 1                     6                7                       6
# 2                     5                5                       6
# 3                     4                5                       4
# 4                     7                7                       7
#
#    q32_tool_difficult_focus  q33_results_accurate  q34_results_trust  \
# 0                         6                     7                  5
# 1                         4                     4                  5
# 2                         5                     3                  4
# 3                         4                     5                  6
# 4                         7                     6                  6
#
#    q35_results_complete  q36_results_relevant  q37_results_useful  \
# 0                     5                     6                   7
# 1                     5                     5                   5
# 2                     4                     6                   3
# 3                     3                     4                   3
# 4                     6                     6                   6
#
#    q40_purchase_likelihood
# 0                        2
# 1                        6
# 2                        5
# 3                        6
# 4                        5
#
# [5 rows x 26 columns]
